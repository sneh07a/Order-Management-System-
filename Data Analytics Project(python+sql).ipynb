# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the data into pandas dataframe
df = pd.read_csv("orders.csv")

# %%
df.head(10)
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
# 5         6  2022-03-13   Not Available   Consumer  United States
# 6         7  2022-12-28  Standard Class   Consumer  United States
# 7         8  2022-01-25  Standard Class   Consumer  United States
# 8         9  2023-03-23   Not Available   Consumer  United States
# 9        10  2023-05-16  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
#read data with na values
df = pd.read_csv("orders.csv",na_values=["Not Available","unknown"])
df.head(10)
plot.show
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
# 5         6  2022-03-13             NaN   Consumer  United States
# 6         7  2022-12-28  Standard Class   Consumer  United States
# 7         8  2022-01-25  Standard Class   Consumer  United States
# 8         9  2023-03-23             NaN   Consumer  United States
# 9        10  2023-05-16  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# ...

# %%
#renames columns names make them lower case and replace spaces with underscore
df.rename(columns={"Order Id":"order_id","City":"city"})
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ","_")
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#make a new column for profit, discount and sale price
df["discount"]=df["list_price"]*df["discount_percent"]*.01
df["sale_price"]=df["list_price"]-df["discount"]
df["profit"]=df["sale_price"]-df["cost_price"]
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#convert order date from object data type to datatime
df["order_date"]=pd.to_datetime(df["order_date"],format="%Y-%m-%d")

# %%
#drop cost proce list price and discount percent Sale price columns
df.drop(columns=["list_price","cost_price","discount_percent"],inplace=True)

# %%
df.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
 # !pip install PyMySQL
 # !pip install mysql-connector-python
# !pip install pymysql

# %%
from sqlalchemy import create_engine
import mysql.connector

# %%
connection_string = "mysql+pymysql://root:@localhost:3306/abcpy"

engine = create_engine(connection_string)
df.to_sql('orders', con=engine, if_exists='replace', index=True)
# Out:
# 9994

# %%
query = "SHOW TABLES;"
df = pd.read_sql(query, engine)
print("Tables in the database:")
print(df)
# Out:
# Tables in the database:
#   Tables_in_abcpy
# 0          orders
# 1              py
# 2           trump
# 3           users

# %%
query = "DESCRIBE orders;"
df = pd.read_sql(query, engine)
print("Description of the 'orders' table:")
print(df)
# Out:
# Description of the 'orders' table:
#            Field        Type Null  Key Default Extra
# 0          index  bigint(20)  YES  MUL    None
# 1       order_id  bigint(20)  YES         None
# 2     order_date    datetime  YES         None
# 3      ship_mode        text  YES         None
# 4        segment        text  YES         None
# 5        country        text  YES         None
# 6           city        text  YES         None
# 7          state        text  YES         None
# 8    postal_code  bigint(20)  YES         None
# 9         region        text  YES         None
# 10      category        text  YES         None
# 11  sub_category        text  YES         None
# 12    product_id        text  YES         None
# 13      quantity  bigint(20)  YES         None
# 14      discount      double  YES         None
# 15    sale_price      double  YES         None
# 16        profit      double  YES         None

# %%
query = "select * from orders limit 5;"
df = pd.read_sql(query, engine)
print(df)
# Out:
#    index  order_id order_date       ship_mode    segment        country  \
# 0      0         1 2023-03-01    Second Class   Consumer  United States
# 1      1         2 2023-08-15    Second Class   Consumer  United States
# 2      2         3 2023-01-10    Second Class  Corporate  United States
# 3      3         4 2022-06-18  Standard Class   Consumer  United States
# 4      4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# ...
